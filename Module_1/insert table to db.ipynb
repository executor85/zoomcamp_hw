# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
df = pd.read_csv('work/green_tripdata_2019-09.csv', nrows=100)

# %%
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1          2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2          2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3          2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4          2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-09-01 00:40:55   2019-09-01 00:48:35                  N
# 96         2  2019-09-01 00:13:52   2019-09-01 00:21:47                  N
# 97         2  2019-09-01 00:37:24   2019-09-01 01:02:31                  N
# 98         2  2019-09-01 00:22:15   2019-09-01 00:29:52                  N
# 99         2  2019-09-01 00:11:53   2019-09-01 00:30:31                  N
#
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@192.168.88.19:5432/ny_taxi')

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
# Empty DataFrame
# Columns: [schemaname, tablename, tableowner, tablespace, hasindexes, hasrules, hastriggers, rowsecurity]
# Index: []

# %%
df.to_sql(name='work/green_tripdata_2019-09.csv', con=engine, index=False)
# Out:
# 100

# %%
query = """
SELECT * FROM "work/green_tripdata_2019-09.csv" LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1         2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2         2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3         2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4         2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# 5         2  2019-09-01 00:55:37   2019-09-01 01:17:02                  N
# 6         2  2019-09-01 00:28:55   2019-09-01 00:52:09                  N
# 7         1  2019-09-01 00:03:13   2019-09-01 00:03:32                  N
# 8         1  2019-09-01 00:15:28   2019-09-01 00:43:22                  N
# 9         2  2019-09-01 00:29:16   2019-09-01 00:30:15                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5           2.00
# ...

# %%
df_iter = pd.read_csv('work/green_tripdata_2019-09.csv', iterator=True,chunksize=10000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 10000

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.to_sql(name='green_tripdata_2019-09.csv', con=engine,if_exists='replace')

# %%
df.head(n=0).to_sql(name='green_tripdata_2019-09.csv', con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_tripdata_2019-09.csv', con=engine,if_exists='append')
# Out:
# CPU times: user 591 ms, sys: 5.95 ms, total: 597 ms
# Wall time: 947 ms
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df = next(df_iter)
    
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_tripdata_2019-09.csv', con=engine,if_exists='append')

    t_end = time()
    
    print('insert another chunk... %.3f' % (t_end - t_start))
# Out:
# insert another chunk... 0.934
# insert another chunk... 0.876
# insert another chunk... 1.014
# insert another chunk... 0.899
# insert another chunk... 0.970
# insert another chunk... 0.868
# insert another chunk... 0.821
# insert another chunk... 1.053
# insert another chunk... 0.933
# insert another chunk... 0.908
# insert another chunk... 0.882
# insert another chunk... 0.906
# insert another chunk... 0.905
# insert another chunk... 0.946
# insert another chunk... 0.849
# insert another chunk... 0.898
# insert another chunk... 0.860
# insert another chunk... 0.937
# insert another chunk... 0.835
# insert another chunk... 0.917
# insert another chunk... 0.993
# insert another chunk... 0.862
# insert another chunk... 1.042
# insert another chunk... 0.914
# insert another chunk... 1.004
# insert another chunk... 0.954
# insert another chunk... 1.084
# insert another chunk... 0.927
# insert another chunk... 0.905
# insert another chunk... 0.927
# insert another chunk... 0.944
# ...
